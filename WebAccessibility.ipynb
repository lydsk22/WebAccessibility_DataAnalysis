# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of website accessibility by taking the top 1M home pages from TRANCO data (12/10/24 - 1/8/25), running the top 100 through WAVE API (https://wave.webaim.org/api/), and analysing that accessibility data.

# %% [markdown]
# # About the Dataset

# %% [markdown]
# **Data Source:** <br>
# We use the Tranco list* [1] generated on 08 January 2025, ...
# * Available at https://tranco-list.eu/list/24L29.
#
# Victor Le Pochat, Tom Van Goethem, Samaneh Tajalizadehkhoob, Maciej Korczyński, and Wouter Joosen. 2019. "Tranco: A Research-Oriented Top Sites Ranking Hardened Against Manipulation," Proceedings of the 26th Annual Network and Distributed System Security Symposium (NDSS 2019). https://doi.org/10.14722/ndss.2019.23386

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import statsmodels.api as sm
from patsy import dmatrices

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
web_access = pd.read_json('saved_data_combined.json')

# %% [markdown]
# # Data Cleaning/Exploration

# %%
web_access.shape
# Out:
# (136, 4)

# %%
web_access.sample(5)
# Out:
#                                                 status  \
# 1             {'success': True, 'httpstatuscode': 200}
# 110  {'success': False, 'error': 'net::ERR_NAME_NOT...
# 31   {'success': False, 'error': 'net::ERR_NAME_NOT...
# 22            {'success': True, 'httpstatuscode': 200}
# 7             {'success': True, 'httpstatuscode': 200}
#
#                                             statistics  \
# 1    {'pagetitle': 'Gandi.net - Gandi.net: Domain N...
# 110                                                NaN
# 31                                                 NaN
# 22   {'pagetitle': 'Error 404 (Not Found)!!1', 'pag...
# 7    {'pagetitle': 'One platform to connect | Zoom'...
#
#                                             categories  old_index
# 1    {'error': {'description': 'Errors', 'count': 9...     102.00
# 110                                                NaN        NaN
# 31                                                 NaN        NaN
# 22   {'error': {'description': 'Errors', 'count': 1...     123.00
# 7    {'error': {'description': 'Errors', 'count': 4...     108.00

# %%
#drop fail rows
web_access_clean = web_access.dropna()
#remove status column because all are success
web_access_clean.pop("status")
#convert old_index col to numeric
pd.to_numeric(web_access_clean.old_index)

web_access_clean
# Out:
#                                             statistics  \
# 0    {'pagetitle': '腾讯网', 'pageurl': 'https://qq.co...
# 1    {'pagetitle': 'Gandi.net - Gandi.net: Domain N...
# 2    {'pagetitle': 'Google Drive: Share Files Onlin...
# 3    {'pagetitle': 'Login | Microsoft 365', 'pageur...
# 5    {'pagetitle': 'Mozilla - Internet for people, ...
# ..                                                 ...
# 129  {'pagetitle': 'Just a moment...', 'pageurl': '...
# 131  {'pagetitle': 'Explore - Find your favourite v...
# 133  {'pagetitle': 'Analytics Tools & Solutions for...
# 134  {'pagetitle': 'Яндекс — быстрый поиск в интерн...
# 135  {'pagetitle': 'Microsoft 365 - Subscription fo...
#
#                                             categories  old_index
# 0    {'error': {'description': 'Errors', 'count': 1...     101.00
# 1    {'error': {'description': 'Errors', 'count': 9...     102.00
# 2    {'error': {'description': 'Errors', 'count': 1...     103.00
# 3    {'error': {'description': 'Errors', 'count': 1...     104.00
# 5    {'error': {'description': 'Errors', 'count': 1...     106.00
# ..                                                 ...        ...
# 129  {'error': {'description': 'Errors', 'count': 1...      93.00
# 131  {'error': {'description': 'Errors', 'count': 1...      95.00
# 133  {'error': {'description': 'Errors', 'count': 2...      97.00
# 134  {'error': {'description': 'Errors', 'count': 0...      98.00
# 135  {'error': {'description': 'Errors', 'count': 1...      99.00
#
# [100 rows x 3 columns]

# %% [markdown]
# # Extracting Nested Data from a Column
#
# Breaking out "statistics" column and "categories" column while maintaining old_index (web page popularity)

# %%
statistics_df = pd.json_normalize(data=web_access_clean["statistics"]).set_index(web_access_clean.old_index)

# %%
cat_df = pd.json_normalize(data = web_access_clean["categories"],
                                      max_level=1,
                                      record_prefix=True).set_index(web_access_clean.old_index)

# %%
comb_df = statistics_df.join(other=cat_df)
comb_df
# Out:
#                                                    pagetitle  \
# old_index
# 101.00                                                   腾讯网
# 102.00     Gandi.net - Gandi.net: Domain Names, Web Hosti...
# 103.00     Google Drive: Share Files Online with Secure C...
# 104.00                                 Login | Microsoft 365
# 106.00        Mozilla - Internet for people, not profit (US)
# ...                                                      ...
# 93.00                                       Just a moment...
# 95.00         Explore - Find your favourite videos on TikTok
# 97.00      Analytics Tools & Solutions for Your Business ...
# 98.00                     Яндекс — быстрый поиск в интернете
# 99.00      Microsoft 365 - Subscription for Productivity ...
#
#                                 pageurl  time  creditsremaining  allitemcount  \
# old_index
# 101.00                   https://qq.com  8.85                27           418
# 102.00                https://gandi.net  3.12                26           268
# 103.00         https://drive.google.com  4.87                25           266
# 104.00      https://officeapps.live.com  2.93                24           290
# 106.00              https://mozilla.org  2.43                23           229
# ...                                 ...   ...               ...           ...
# 93.00            https://cloudflare.net  3.32                32             6
# 95.00                https://tiktok.com  8.54                31           138
# 97.00      https://google-analytics.com  3.12                30           236
# 98.00                https://yandex.net  5.93                29            98
# 99.00             https://office365.com  8.73                28          1229
#
#            totalelements                                            waveurl  \
# old_index
# 101.00              2174   http://wave.webaim.org/report?url=https://qq.com
# 102.00              1343  http://wave.webaim.org/report?url=https://gand...
# 103.00              2246  http://wave.webaim.org/report?url=https://driv...
# 104.00               983  http://wave.webaim.org/report?url=https://offi...
# 106.00              1098  http://wave.webaim.org/report?url=https://mozi...
# ...                  ...                                                ...
# 93.00                 42  http://wave.webaim.org/report?url=https://clou...
# 95.00                922  http://wave.webaim.org/report?url=https://tikt...
# 97.00                829  http://wave.webaim.org/report?url=https://goog...
# 98.00                280  http://wave.webaim.org/report?url=https://yand...
# 99.00               3388  http://wave.webaim.org/report?url=https://offi...
#
#           error.description  error.count contrast.description  contrast.count  \
# old_index
# 101.00               Errors          113      Contrast Errors             181
# 102.00               Errors            9      Contrast Errors               5
# 103.00               Errors            1      Contrast Errors               0
# 104.00               Errors            1      Contrast Errors               0
# 106.00               Errors            1      Contrast Errors               0
# ...                     ...          ...                  ...             ...
# 93.00                Errors            1      Contrast Errors               0
# 95.00                Errors           14      Contrast Errors               8
# 97.00                Errors            2      Contrast Errors               0
# 98.00                Errors            0      Contrast Errors               3
# 99.00                Errors           11      Contrast Errors               0
#
#           alert.description  alert.count feature.description  feature.count  \
# old_index
# 101.00               Alerts           90            Features              2
# 102.00               Alerts           16            Features             18
# 103.00               Alerts            9            Features             83
# 104.00               Alerts            3            Features             29
# 106.00               Alerts           12            Features            125
# ...                     ...          ...                 ...            ...
# 93.00                Alerts            1            Features              1
# 95.00                Alerts           25            Features              5
# 97.00                Alerts           42            Features             12
# 98.00                Alerts            3            Features              1
# 99.00                Alerts           12            Features            101
#
#           structure.description  structure.count aria.description  aria.count
# old_index
# 101.00      Structural Elements                6             ARIA          26
# 102.00      Structural Elements              107             ARIA         113
# 103.00      Structural Elements               53             ARIA         120
# 104.00      Structural Elements               61             ARIA         196
# 106.00      Structural Elements               69             ARIA          22
# ...                         ...              ...              ...         ...
# 93.00       Structural Elements                3             ARIA           0
# 95.00       Structural Elements                7             ARIA          79
# 97.00       Structural Elements               71             ARIA         109
# 98.00       Structural Elements               14             ARIA          77
# 99.00       Structural Elements              114             ARIA         991
#
# [100 rows x 19 columns]

# %% [markdown]
# # Further Clean Data by Removing Unnecessary Columns

# %%
pop_cols = ["time", "creditsremaining", "waveurl", "error.description", "contrast.description", "alert.description", "feature.description", "structure.description", "aria.description"]
for col in pop_cols:
  comb_df.pop(col)
comb_df
# Out:
#                                                    pagetitle  \
# old_index
# 101.00                                                   腾讯网
# 102.00     Gandi.net - Gandi.net: Domain Names, Web Hosti...
# 103.00     Google Drive: Share Files Online with Secure C...
# 104.00                                 Login | Microsoft 365
# 106.00        Mozilla - Internet for people, not profit (US)
# ...                                                      ...
# 93.00                                       Just a moment...
# 95.00         Explore - Find your favourite videos on TikTok
# 97.00      Analytics Tools & Solutions for Your Business ...
# 98.00                     Яндекс — быстрый поиск в интернете
# 99.00      Microsoft 365 - Subscription for Productivity ...
#
#                                 pageurl  allitemcount  totalelements  \
# old_index
# 101.00                   https://qq.com           418           2174
# 102.00                https://gandi.net           268           1343
# 103.00         https://drive.google.com           266           2246
# 104.00      https://officeapps.live.com           290            983
# 106.00              https://mozilla.org           229           1098
# ...                                 ...           ...            ...
# 93.00            https://cloudflare.net             6             42
# 95.00                https://tiktok.com           138            922
# 97.00      https://google-analytics.com           236            829
# 98.00                https://yandex.net            98            280
# 99.00             https://office365.com          1229           3388
#
#            error.count  contrast.count  alert.count  feature.count  \
# old_index
# 101.00             113             181           90              2
# 102.00               9               5           16             18
# 103.00               1               0            9             83
# 104.00               1               0            3             29
# 106.00               1               0           12            125
# ...                ...             ...          ...            ...
# 93.00                1               0            1              1
# 95.00               14               8           25              5
# 97.00                2               0           42             12
# 98.00                0               3            3              1
# 99.00               11               0           12            101
#
#            structure.count  aria.count
# old_index
# 101.00                   6          26
# 102.00                 107         113
# 103.00                  53         120
# 104.00                  61         196
# 106.00                  69          22
# ...                    ...         ...
# 93.00                    3           0
# 95.00                    7          79
# 97.00                   71         109
# 98.00                   14          77
# 99.00                  114         991
#
# [100 rows x 10 columns]

# %% [markdown]
# # Find Webpages with the Most Errors

# %%
comb_df.sort_values('allitemcount', ascending=False).head()
# Out:
#                                                    pagetitle  \
# old_index
# 118.00     Samsung US | Mobile | TV | Home Electronics | ...
# 38.00                            Android Apps on Google Play
# 99.00      Microsoft 365 - Subscription for Productivity ...
# 24.00      Microsoft Outlook (formerly Hotmail): Free ema...
# 19.00             Cloud Computing Services | Microsoft Azure
#
#                            pageurl  allitemcount  totalelements  error.count  \
# old_index
# 118.00         https://samsung.com          2716           6760            3
# 38.00      https://play.google.com          1839           5098           24
# 99.00        https://office365.com          1229           3388           11
# 24.00             https://live.com          1199           4071           20
# 19.00            https://azure.com          1088           3662           19
#
#            contrast.count  alert.count  feature.count  structure.count  \
# old_index
# 118.00                 43          100            262              188
# 38.00                  73          564             62               11
# 99.00                   0           12            101              114
# 24.00                   3           28             70              125
# 19.00                   0           16            110              164
#
#            aria.count
# old_index
# 118.00           2120
# 38.00            1105
# 99.00             991
# 24.00             953
# 19.00             779

# %% [markdown]
# ARIA errors are the most common by far

# %% [markdown]
# # Find Webpages with the Most Errors as a Percentage of Total DOM Elements

# %%
comb_df["total_percent_error"] = comb_df["allitemcount"].mul(100).div(comb_df["totalelements"])
comb_df.sort_values("total_percent_error", ascending=False).head()
# Out:
#           pagetitle                                   pageurl  allitemcount  \
# old_index
# 64.00                 https://settings-win.data.microsoft.com             4
# 121.00               https://mobile.events.data.microsoft.com             4
# 17.00                       https://events.data.microsoft.com             4
# 62.00                                   https://node.e2ro.com             4
# 90.00                                  https://ecs.office.com             4
#
#            totalelements  error.count  contrast.count  alert.count  \
# old_index
# 64.00                  4            2               0            2
# 121.00                 4            2               0            2
# 17.00                  4            2               0            2
# 62.00                  5            2               0            2
# 90.00                  5            2               0            2
#
#            feature.count  structure.count  aria.count  total_percent_error
# old_index
# 64.00                  0                0           0               100.00
# 121.00                 0                0           0               100.00
# 17.00                  0                0           0               100.00
# 62.00                  0                0           0                80.00
# 90.00                  0                0           0                80.00

# %% [markdown]
# In above example you can see that many web pages have very few elements. This leads me to believe they are not valid data. In the next step I will remove any webpage with fewer than or equal to 100 elements.

# %%
comb_df = comb_df.drop(comb_df[comb_df["totalelements"] <= 100].index)
comb_df.sort_values("totalelements", ascending=True)
# Out:
#                                                    pagetitle  \
# old_index
# 67.00             Web Accessibility in Mind Conference: Home
# 46.00                                Sign in to your account
# 107.00                          X. It’s what’s happening / X
# 13.00                           X. It’s what’s happening / X
# 82.00      Welcome to the home of the Network Time Protoc...
# ...                                                      ...
# 99.00      Microsoft 365 - Subscription for Productivity ...
# 19.00             Cloud Computing Services | Microsoft Azure
# 24.00      Microsoft Outlook (formerly Hotmail): Free ema...
# 38.00                            Android Apps on Google Play
# 118.00     Samsung US | Mobile | TV | Home Electronics | ...
#
#                                      pageurl  allitemcount  totalelements  \
# old_index
# 67.00              https://domaincontrol.com            33            112
# 46.00      https://login.microsoftonline.com            33            127
# 107.00                         https://x.com            32            177
# 13.00                    https://twitter.com            32            177
# 82.00                        https://ntp.org            47            179
# ...                                      ...           ...            ...
# 99.00                  https://office365.com          1229           3388
# 19.00                      https://azure.com          1088           3662
# 24.00                       https://live.com          1199           4071
# 38.00                https://play.google.com          1839           5098
# 118.00                   https://samsung.com          2716           6760
#
#            error.count  contrast.count  alert.count  feature.count  \
# old_index
# 67.00                0               0            1             15
# 46.00                8               0            2              2
# 107.00               0               1            2              1
# 13.00                0               1            2              1
# 82.00                5              10            7              2
# ...                ...             ...          ...            ...
# 99.00               11               0           12            101
# 19.00               19               0           16            110
# 24.00               20               3           28             70
# 38.00               24              73          564             62
# 118.00               3              43          100            262
#
#            structure.count  aria.count  total_percent_error
# old_index
# 67.00                   17           0                29.46
# 46.00                    2          19                25.98
# 107.00                   3          25                18.08
# 13.00                    3          25                18.08
# 82.00                    6          17                26.26
# ...                    ...         ...                  ...
# 99.00                  114         991                36.28
# 19.00                  164         779                29.71
# 24.00                  125         953                29.45
# 38.00                   11        1105                36.07
# 118.00                 188        2120                40.18
#
# [74 rows x 11 columns]

# %% [markdown]
# # Again! Find Webpages with the Most Errors as a Percentage of Total DOM Elements#

# %%
comb_df.sort_values("total_percent_error", ascending=False).head(15)
# Out:
#                                                    pagetitle  \
# old_index
# 133.00                                           Google Help
# 39.00                                Search - Microsoft Bing
# 55.00                                              Pinterest
# 33.00                                              Wikipedia
# 77.00               Spotify - Web Player: Music for everyone
# 118.00     Samsung US | Mobile | TV | Home Electronics | ...
# 20.00                            LinkedIn: Log In or Sign Up
# 126.00     Telekom | Mobilfunk, Festnetz & Internet, TV A...
# 80.00                              Sign in - Google Accounts
# 70.00                              Sign in - Google Accounts
# 0.00                                                  Google
# 16.00                                                 Google
# 26.00                                                 Google
# 44.00                                                 Google
# 99.00      Microsoft 365 - Subscription for Productivity ...
#
#                                  pageurl  allitemcount  totalelements  \
# old_index
# 133.00         https://googledomains.com           642            938
# 39.00                   https://bing.com           333            579
# 55.00              https://pinterest.com           691           1382
# 33.00              https://wikipedia.org           469           1047
# 77.00                https://spotify.com           903           2106
# 118.00               https://samsung.com          2716           6760
# 20.00               https://linkedin.com           320            798
# 126.00                https://telekom.de           446           1139
# 80.00        https://accounts.google.com           235            618
# 70.00            https://docs.google.com           235            618
# 0.00                  https://google.com           143            382
# 16.00             https://www.google.com           143            382
# 26.00            https://googlevideo.com           143            382
# 44.00      https://googlesyndication.com           142            382
# 99.00              https://office365.com          1229           3388
#
#            error.count  contrast.count  alert.count  feature.count  \
# old_index
# 133.00              24               0            6             91
# 39.00                6               0           25             33
# 55.00                3              11            8            193
# 33.00                6               1           10            428
# 77.00                4               1           61             51
# 118.00               3              43          100            262
# 20.00               37               0            0             10
# 126.00               5              34           87             57
# 80.00                1               1            3              2
# 70.00                1               1            3              2
# 0.00                 1               0            1             12
# 16.00                1               0            1             12
# 26.00                1               0            1             12
# 44.00                1               0            1             12
# 99.00               11               0           12            101
#
#            structure.count  aria.count  total_percent_error
# old_index
# 133.00                 190         331                68.44
# 39.00                   42         227                57.51
# 55.00                   10         466                50.00
# 33.00                   19           5                44.79
# 77.00                   42         744                42.88
# 118.00                 188        2120                40.18
# 20.00                   36         237                40.10
# 126.00                  51         212                39.16
# 80.00                    7         221                38.03
# 70.00                    7         221                38.03
# 0.00                     5         124                37.43
# 16.00                    5         124                37.43
# 26.00                    5         124                37.43
# 44.00                    5         123                37.17
# 99.00                  114         991                36.28

# %% [markdown]
# Now our dataset has 74 viable websites. A few rows look like duplicates, but after checking, they are sign in pages for different google services, so they'll remain in the dataset.

# %% [markdown]
# #Is Total Percent Error Dependent on the Total Number of DOM Elements?
#
# Hypothesis: As webppages increase in complexity (more DOM elements), there are increasingly more errors, leading to an increased total percent error.

# %%
#create scatter plot from comb_df using totalelements and total_percent_error as x and y columns, respectively
scatter = px.scatter(comb_df,
                     x = comb_df["totalelements"],
                     y = comb_df["total_percent_error"],
                     title = "Webpage DOM Elements v Total % Error",
                     color = comb_df["allitemcount"],
                     color_continuous_scale=px.colors.sequential.Agsunset,
                     width = 1000,
                     height = 750,
                     hover_data = ["pageurl", "totalelements", "total_percent_error"],
                     trendline="ols",
                     )

#update the scatter plot with x and y axis titles and a legend
scatter.update_layout(xaxis = {"title":"Total DOM Elements"},
                      yaxis = {"title": "Total Percent Error"},
                      legend = {"yanchor": "top",
                                "y": 0.995,
                                "x": 0.005,
                                "xanchor": "left",
                                "bgcolor": "White",
                                "bordercolor":"LightSteelBlue",
                                "borderwidth": 2,
                                "itemsizing": "constant",
                                },
                      hoverlabel = {"align": "left",
                                    "bgcolor": "rgb(255,255,255)"
                                   }
                      )

#increase the size of markers and increase contrast with outlines
scatter.update_traces(marker={"size":15,
                              "line":{"width":2,
                                      "color":"Black"
                                      }
                              }
                      )

#display trendline values in legend
tl = px.get_trendline_results(scatter)
a = tl.iloc[0]["px_fit_results"].params[0]
b = tl.iloc[0]["px_fit_results"].params[1]
scatter.data[0].name = 'websites'
scatter.data[0].showlegend = True
scatter.data[1].name = scatter.data[1].name  + ' y = ' + str(round(a, 2)) + ' + ' + str(round(b, 2)) + 'x'
rsq = tl.iloc[0]["px_fit_results"].rsquared
scatter.add_trace(go.Scatter(x=[100], y=[100],
                         name = "R-squared" + ' = ' + str(round(rsq, 2)),
                         showlegend=True,
                         mode='markers',
                         marker=dict(color='rgba(0,0,0,0)')
                         ))
scatter.data[1].showlegend = True

# results = px.get_trendline_results(scatter)
# results = results.iloc[0]["px_fit_results"].summary()
# print(results)

#Outline the area with most data points
scatter.add_shape(
    name="Error Area",
    showlegend=True,
    type="rect",
    line=dict(dash="dash"),
    x0=0,
    x1=2000,
    y0=10,
    y1=40,
)

scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="269eb036-d00f-42e8-95c3-1776973ce378" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("269eb036-d00f-42e8-95c3-1776973ce378")) {                    Plotly.newPlot(                        "269eb036-d00f-42e8-95c3-1776973ce378",                        [{"customdata":[["https:\u002f\u002fqq.com"],["https:\u002f\u002fgandi.net"],["https:\u002f\u002fdrive.google.com"],["https:\u002f\u002fofficeapps.live.com"],["https:\u002f\u002fmozilla.org"],["https:\u002f\u002fx.com"],["https:\u002f\u002fzoom.us"],["https:\u002f\u002fplus.google.com"],["https:\u002f\u002fblogspot.com"],["https:\u002f\u002fopera.com"],["https:\u002f\u002fplayer.vimeo.com"],["https:\u002f\u002fcloudflare-dns.com"],["https:\u002f\u002fsamsung.com"],["https:\u002f\u002fbaidu.com"],["https:\u002f\u002fmts.ru"],["https:\u002f\u002ftelekom.de"],["https:\u002f\u002fsnapchat.com"],["https:\u002f\u002fapi.whatsapp.com"],["https:\u002f\u002feuropa.eu"],["https:\u002f\u002fgoogledomains.com"],["https:\u002f\u002fpolicies.google.com"],["https:\u002f\u002fintuit.com"],["https:\u002f\u002fgoogle.com"],["https:\u002f\u002fmicrosoft.com"],["https:\u002f\u002fmail.ru"],["https:\u002f\u002ffacebook.com"],["https:\u002f\u002fapple.com"],["https:\u002f\u002ftwitter.com"],["https:\u002f\u002finstagram.com"],["https:\u002f\u002fwww.google.com"],["https:\u002f\u002fazure.com"],["https:\u002f\u002flinkedin.com"],["https:\u002f\u002foffice.com"],["https:\u002f\u002flive.com"],["https:\u002f\u002fgooglevideo.com"],["https:\u002f\u002famazon.com"],["https:\u002f\u002ffbcdn.net"],["https:\u002f\u002fworkers.dev"],["https:\u002f\u002fwikipedia.org"],["https:\u002f\u002fdoubleclick.net"],["https:\u002f\u002fplay.google.com"],["https:\u002f\u002fbing.com"],["https:\u002f\u002fgithub.com"],["https:\u002f\u002fwordpress.org"],["https:\u002f\u002fgooglesyndication.com"],["https:\u002f\u002ffastly.net"],["https:\u002f\u002flogin.microsoftonline.com"],["https:\u002f\u002fnetflix.com"],["https:\u002f\u002fwhatsapp.net"],["https:\u002f\u002fpinterest.com"],["https:\u002f\u002fen.wikipedia.org"],["https:\u002f\u002fdigicert.com"],["https:\u002f\u002fyahoo.com"],["https:\u002f\u002fsharepoint.com"],["https:\u002f\u002fadobe.com"],["https:\u002f\u002fdomaincontrol.com"],["https:\u002f\u002fgoo.gl"],["https:\u002f\u002fdocs.google.com"],["https:\u002f\u002fmaps.google.com"],["https:\u002f\u002fwhatsapp.com"],["https:\u002f\u002fvimeo.com"],["https:\u002f\u002fspotify.com"],["https:\u002f\u002fwindows.net"],["https:\u002f\u002faccounts.google.com"],["https:\u002f\u002fntp.org"],["https:\u002f\u002fapps.apple.com"],["https:\u002f\u002froblox.com"],["https:\u002f\u002fbit.ly"],["https:\u002f\u002fnic.ru"],["https:\u002f\u002fwordpress.com"],["https:\u002f\u002ftiktok.com"],["https:\u002f\u002fgoogle-analytics.com"],["https:\u002f\u002fyandex.net"],["https:\u002f\u002foffice365.com"]],"hovertemplate":"totalelements=%{x}\u003cbr\u003etotal_percent_error=%{y}\u003cbr\u003epageurl=%{customdata[0]}\u003cbr\u003eallitemcount=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[418,268,266,290,229,32,563,328,83,132,281,63,2716,65,271,446,198,70,275,642,59,389,143,352,544,74,581,32,51,143,1088,320,284,1199,143,307,74,183,469,294,1839,333,354,131,142,390,33,270,99,691,372,585,440,1061,46,33,214,235,44,99,302,903,201,235,47,712,172,418,124,340,138,236,98,1229],"coloraxis":"coloraxis","symbol":"circle","line":{"color":"Black","width":2},"size":15},"mode":"markers","name":"websites","orientation":"v","showlegend":true,"x":[2174,1343,2246,983,1098,177,1964,1948,290,715,1468,1112,6760,449,1543,1139,615,739,905,938,292,1982,382,1062,2888,238,1754,177,393,382,3662,798,985,407 ...

# %% [markdown]
# Conslusion: More elements doesn't necessarily mean more likely to have more errors (very low R^2). Most websites have between 0 - 2,000 DOM elements,
# 0 - 1,000 error items, and 10-40% total errors. The more elements in a webpage the more errors there are, but there's not a higher percentage of error.

# %% [markdown]
# #Is a Popular Webpage Less Likely to Have Errors?
#
# Hypothesis: The more popular a webpage is, the less likely it is to have accessibility errors.

# %%
#create scatter plot from comb_df using the index and total_percent_error as x and y columns, respectively
scatter = px.scatter(comb_df,
                     x = comb_df.index,
                     y = comb_df["total_percent_error"],
                     title = "Webpage Popularity v Total % Error",
                     color = comb_df["totalelements"],
                     color_continuous_scale=px.colors.sequential.Agsunset,
                     width = 1000,
                     height = 750,
                     hover_data = ["pageurl", "allitemcount", "totalelements", "total_percent_error"],
                     trendline="ols",
                     )

#update the scatter plot with x and y axis titles and a legend
scatter.update_layout(xaxis = {"title":"Webpage Popularity"},
                      yaxis = {"title": "Total Percent Error"},
                      legend = {"yanchor": "top",
                                "y": 0.995,
                                "x": 0.005,
                                "xanchor": "left",
                                "bgcolor": "White",
                                "bordercolor":"LightSteelBlue",
                                "borderwidth": 2,
                                "itemsizing": "constant",
                                },
                      hoverlabel = {"align": "left",
                                    "bgcolor": "rgb(255,255,255)"
                                   }
                      )

#increase the size of markers and increase contrast with outlines
scatter.update_traces(marker={"size":15,
                              "line":{"width":2,
                                      "color":"Black"
                                      }
                              }
                      )

#display trendline values in legend
tl = px.get_trendline_results(scatter)
a = tl.iloc[0]["px_fit_results"].params[0]
b = tl.iloc[0]["px_fit_results"].params[1]
scatter.data[0].name = 'websites'
scatter.data[0].showlegend = True
scatter.data[1].name = scatter.data[1].name  + ' y = ' + str(round(a, 2)) + ' + ' + str(round(b, 2)) + 'x'
rsq = tl.iloc[0]["px_fit_results"].rsquared
scatter.add_trace(go.Scatter(x=[100], y=[100],
                         name = "R-squared" + ' = ' + str(round(rsq, 2)),
                         showlegend=True,
                         mode='markers',
                         marker=dict(color='rgba(0,0,0,0)')
                         ))
scatter.data[1].showlegend = True

#Outline the area with the most data points
scatter.add_shape(
    name="Error Area",
    showlegend=True,
    type="rect",
    line={"dash":"dash"},
    x0=0,
    x1=136,
    y0=10,
    y1=40,
)

# results = px.get_trendline_results(scatter)
# results = results.iloc[0]["px_fit_results"].summary()
# print(results)

scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3d5f0de5-4ad9-4d2a-b9be-7ee757c64cde" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d5f0de5-4ad9-4d2a-b9be-7ee757c64cde")) {                    Plotly.newPlot(                        "3d5f0de5-4ad9-4d2a-b9be-7ee757c64cde",                        [{"customdata":[["https:\u002f\u002fqq.com",418,2174],["https:\u002f\u002fgandi.net",268,1343],["https:\u002f\u002fdrive.google.com",266,2246],["https:\u002f\u002fofficeapps.live.com",290,983],["https:\u002f\u002fmozilla.org",229,1098],["https:\u002f\u002fx.com",32,177],["https:\u002f\u002fzoom.us",563,1964],["https:\u002f\u002fplus.google.com",328,1948],["https:\u002f\u002fblogspot.com",83,290],["https:\u002f\u002fopera.com",132,715],["https:\u002f\u002fplayer.vimeo.com",281,1468],["https:\u002f\u002fcloudflare-dns.com",63,1112],["https:\u002f\u002fsamsung.com",2716,6760],["https:\u002f\u002fbaidu.com",65,449],["https:\u002f\u002fmts.ru",271,1543],["https:\u002f\u002ftelekom.de",446,1139],["https:\u002f\u002fsnapchat.com",198,615],["https:\u002f\u002fapi.whatsapp.com",70,739],["https:\u002f\u002feuropa.eu",275,905],["https:\u002f\u002fgoogledomains.com",642,938],["https:\u002f\u002fpolicies.google.com",59,292],["https:\u002f\u002fintuit.com",389,1982],["https:\u002f\u002fgoogle.com",143,382],["https:\u002f\u002fmicrosoft.com",352,1062],["https:\u002f\u002fmail.ru",544,2888],["https:\u002f\u002ffacebook.com",74,238],["https:\u002f\u002fapple.com",581,1754],["https:\u002f\u002ftwitter.com",32,177],["https:\u002f\u002finstagram.com",51,393],["https:\u002f\u002fwww.google.com",143,382],["https:\u002f\u002fazure.com",1088,3662],["https:\u002f\u002flinkedin.com",320,798],["https:\u002f\u002foffice.com",284,985],["https:\u002f\u002flive.com",1199,4071],["https:\u002f\u002fgooglevideo.com",143,382],["https:\u002f\u002famazon.com",307,1387],["https:\u002f\u002ffbcdn.net",74,238],["https:\u002f\u002fworkers.dev",183,570],["https:\u002f\u002fwikipedia.org",469,1047],["https:\u002f\u002fdoubleclick.net",294,836],["https:\u002f\u002fplay.google.com",1839,5098],["https:\u002f\u002fbing.com",333,579],["https:\u002f\u002fgithub.com",354,1405],["https:\u002f\u002fwordpress.org",131,639],["https:\u002f\u002fgooglesyndication.com",142,382],["https:\u002f\u002ffastly.net",390,1504],["https:\u002f\u002flogin.microsoftonline.com",33,127],["https:\u002f\u002fnetflix.com",270,1159],["https:\u002f\u002fwhatsapp.net",99,1211],["https:\u002f\u002fpinterest.com",691,1382],["https:\u002f\u002fen.wikipedia.org",372,1395],["https:\u002f\u002fdigicert.com",585,2077],["https:\u002f\u002fyahoo.com",440,2062],["https:\u002f\u002fsharepoint.com",1061,3128],["https:\u002f\u002fadobe.com",46,336],["https:\u002f\u002fdomaincontrol.com",33,112],["https:\u002f\u002fgoo.gl",214,656],["https:\u002f\u002fdocs.google.com",235,618],["https:\u002f\u002fmaps.google.com",44,235],["https:\u002f\u002fwhatsapp.com",99,1211],["https:\u002f\u002fvimeo.com",302,1548],["https:\u002f\u002fspotify.com",903,2106],["https:\u002f\u002fwindows.net",201,1017],["https:\u002f\u002faccounts.google.com",235,618],["https:\u002f\u002fntp.org",47,179],["https:\u002f\u002fapps.apple.com",712,2209],["https:\u002f\u002froblox.com",172,554],["https:\u002f\u002fbit.ly",418,1414],["https:\u002f\u002fnic.ru",124,857],["https:\u002f\u002fwordpress.com",340,1393],["https:\u002f\u002ftiktok.com",138,922],["https:\u002f\u002fgoogle-analytics.com",236,829],["https:\u002f\u002fyandex.net",98,280],["https:\u002f\u002foffice365.com",1229,3388]],"hovertemplate":"old_index=%{x}\u003cbr\u003etotal_percent_error=%{y}\u003cbr\u003epageurl=%{customdata[0]}\u003cbr\u003eallitemcount=%{customdata[1]}\u003cbr\u003etotalelements=%{marker.color}\u003cextra\u003e\u00 ...

# %% [markdown]
# Conclusion: A webpage being more or less popular (having a lower or higher old_index, respectively) doesn't necessarily mean it will have a higher or lower percentage of errors. Nor does it mean that the page will have more or fewer total DOM elements. The majority of webpages, regardless of popularity, have between 10-40% errors.

# %% [markdown]
# #What are the Most Common Types of Errors?

# %%
#create a new dataframe of error count and error percentage
errors_df = pd.DataFrame({"page": comb_df["pageurl"],
                          "total_features": comb_df["totalelements"],
                          "total_errors": comb_df["allitemcount"],
                          "total_errors_percent": comb_df["total_percent_error"],
                          "error_count":comb_df["error.count"],
                          "error_percent": comb_df["error.count"].mul(100).div(comb_df["allitemcount"]),
                          "contrast_count":comb_df["contrast.count"],
                          "contrast_percent": comb_df["contrast.count"].mul(100).div(comb_df["allitemcount"]),
                          "alert_count":comb_df["alert.count"],
                          "alert_percent": comb_df["alert.count"].mul(100).div(comb_df["allitemcount"]),
                          "feature_count":comb_df["feature.count"],
                          "feature_percent": comb_df["feature.count"].mul(100).div(comb_df["allitemcount"]),
                          "structure_count":comb_df["structure.count"],
                          "structure_percent": comb_df["structure.count"].mul(100).div(comb_df["allitemcount"]),
                          "aria_count":comb_df["aria.count"],
                          "aria_percent": comb_df["aria.count"].mul(100).div(comb_df["allitemcount"]),
                         }
          )

#create a pie chart of the error percentages
errors_percent_cols = [name for name in errors_df.columns if "percent" in name and name != "total_errors_percent"]
fig = px.pie(labels=[error_type[:-8].title() for error_type in errors_percent_cols],
             values=[errors_df[error_type].mean() for error_type in errors_percent_cols],
             title="Average Error Type % Per Webpage",
             names=[error_type[:-8].title() for error_type in errors_percent_cols],
             )

#labels of percentage go outside the pie chart
fig.update_traces(textposition="outside", textinfo="percent+label")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8f8f3b9a-5b5b-437a-97c0-7938ce61a858" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f8f3b9a-5b5b-437a-97c0-7938ce61a858")) {                    Plotly.newPlot(                        "8f8f3b9a-5b5b-437a-97c0-7938ce61a858",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Error","Contrast","Alert","Feature","Structure","Aria"],"legendgroup":"","name":"","showlegend":true,"values":[3.6961065492312297,5.883986470422995,8.637137220431674,13.656925434218634,16.624368783303737,51.501475542391724],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[ ...

# %% [markdown]
# ARIA errors are by far the most common type of error at, on average, 51.5% of a website's errors being type ARIA. The next most common is structure, at an average of 16.6% of total errors per website.

# %%
errors_melt_df = pd.melt(errors_df.sort_values("total_errors", ascending=False).head(15),
                         id_vars=["page"],
                         value_vars=["error_count",
                                     "contrast_count",
                                     "alert_count",
                                     "feature_count",
                                     "structure_count",
                                     "aria_count",
                                     ],
                         var_name="all_error_types",
                         value_name="all_error_counts",
                         col_level=0,
                         ignore_index=True
                         )

errors_melt_df = pd.merge(left=errors_melt_df, right=errors_df[["page", "total_errors"]], how="left", on="page")
errors_melt_df["percent"] = errors_melt_df["all_error_counts"].div(errors_melt_df["total_errors"]).map('{:.2%}'.format)

fig = px.bar(errors_melt_df,
             x="page",
             y="all_error_counts",
             color="all_error_types",
             text="percent",
             title="The Top 15 Most Error-Prone Websites by Error Type",
             height=1200,
             hover_data = ["page", "total_errors"],
)

fig.update_layout(xaxis = {"title":"Top 15 Most Error-Prone Websites"},
                      yaxis = {"title": "Total Error Count"},
                      legend = {"title": "Error Types"},
                      hoverlabel = {"align": "left",
                                    "bgcolor": "rgb(255,255,255)"
                                   }
                      )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="061437fb-a34a-414b-bd06-40387be7ad10" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("061437fb-a34a-414b-bd06-40387be7ad10")) {                    Plotly.newPlot(                        "061437fb-a34a-414b-bd06-40387be7ad10",                        [{"alignmentgroup":"True","customdata":[[2716],[1839],[1229],[1199],[1088],[1061],[903],[712],[691],[642],[585],[581],[563],[544],[469]],"hovertemplate":"all_error_types=error_count\u003cbr\u003epage=%{x}\u003cbr\u003eall_error_counts=%{y}\u003cbr\u003epercent=%{text}\u003cbr\u003etotal_errors=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"error_count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"error_count","offsetgroup":"error_count","orientation":"v","showlegend":true,"text":["0.11%","1.31%","0.90%","1.67%","1.75%","0.66%","0.44%","0.56%","0.43%","3.74%","0.68%","0.00%","0.71%","6.25%","1.28%"],"textposition":"auto","x":["https:\u002f\u002fsamsung.com","https:\u002f\u002fplay.google.com","https:\u002f\u002foffice365.com","https:\u002f\u002flive.com","https:\u002f\u002fazure.com","https:\u002f\u002fsharepoint.com","https:\u002f\u002fspotify.com","https:\u002f\u002fapps.apple.com","https:\u002f\u002fpinterest.com","https:\u002f\u002fgoogledomains.com","https:\u002f\u002fdigicert.com","https:\u002f\u002fapple.com","https:\u002f\u002fzoom.us","https:\u002f\u002fmail.ru","https:\u002f\u002fwikipedia.org"],"xaxis":"x","y":[3,24,11,20,19,7,4,4,3,24,4,0,4,34,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2716],[1839],[1229],[1199],[1088],[1061],[903],[712],[691],[642],[585],[581],[563],[544],[469]],"hovertemplate":"all_error_types=contrast_count\u003cbr\u003epage=%{x}\u003cbr\u003eall_error_counts=%{y}\u003cbr\u003epercent=%{text}\u003cbr\u003etotal_errors=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"contrast_count","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"contrast_count","offsetgroup":"contrast_count","orientation":"v","showlegend":true,"text":["1.58%","3.97%","0.00%","0.25%","0.00%","0.00%","0.11%","2.11%","1.59%","0.00%","7.86%","7.06%","1.07%","16.91%","0.21%"],"textposition":"auto","x":["https:\u002f\u002fsamsung.com","https:\u002f\u002fplay.google.com","https:\u002f\u002foffice365.com","https:\u002f\u002flive.com","https:\u002f\u002fazure.com","https:\u002f\u002fsharepoint.com","https:\u002f\u002fspotify.com","https:\u002f\u002fapps.apple.com","https:\u002f\u002fpinterest.com","https:\u002f\u002fgoogledomains.com","https:\u002f\u002fdigicert.com","https:\u002f\u002fapple.com","https:\u002f\u002fzoom.us","https:\u002f\u002fmail.ru","https:\u002f\u002fwikipedia.org"],"xaxis":"x","y":[43,73,0,3,0,0,1,15,11,0,46,41,6,92,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2716],[1839],[1229],[1199],[1088],[1061],[903],[712],[691],[642],[585],[581],[563],[544],[469]],"hovertemplate":"all_error_types=alert_count\u003cbr\u003epage=%{x}\u003cbr\u003eall_error_counts=%{y}\u003cbr\u003epercent=%{text}\u003cbr\u003etotal_errors=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"alert_count","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"alert_count","offsetgroup":"alert_count","orientation":"v","showlegend":true,"text":["3.68%","30.67%","0.98%","2.34%","1.47%","1.41%","6.76%","6.74%","1.16%","0.93%","14.36%","4.82%","22.20%","23.53%","2.13%"],"textposition":"auto","x":["https:\u002f\u002fsamsung.com","https:\u002f\u002fplay.google.com","https:\u002f\u002foffice365.com","https:\u002f\u002flive.com","https:\u002f\u002fazure.com","https:\u002f\u002fsharepoint.com","https:\u002f\u002fspotify.com","https:\u002f\u002fapps.apple.co ...
